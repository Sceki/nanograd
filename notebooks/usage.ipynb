# %%
import sys
sys.path.append('../')

# %%
from nanograd.engine import Value
x = Value(2.0)
y = Value(3.0)

f = x.eml(y)
f.backward()

print(f)   # forward value
print(x)   # df/dx = exp(x)
print(y)   # df/dy = -1/y
# Out:
# Value(data=6.29044381026254, grad=1.0)
# Value(data=2.0, grad=7.38905609893065)
# Value(data=3.0, grad=-0.3333333333333333)
